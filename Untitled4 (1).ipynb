# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Step 1: Load and Preprocess Data
vocab_size = 10000  # Use the top 10,000 most frequent words
max_length = 500    # Limit reviews to 500 words
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences to ensure equal input length
x_train = pad_sequences(x_train, maxlen=max_length, padding='post', truncating='post')
x_test = pad_sequences(x_test, maxlen=max_length, padding='post', truncating='post')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Step 2: Define the RNN Model
model = Sequential([
    Embedding(vocab_size, 64),  # Embedding layer for word vectors
    SimpleRNN(64, activation='tanh', return_sequences=False),  # RNN layer
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Step 3: Train the Model
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 194ms/step - accuracy: 0.5245 - loss: 0.6767 - val_accuracy: 0.5050 - val_loss: 0.7148
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 189ms/step - accuracy: 0.5303 - loss: 0.6665 - val_accuracy: 0.5038 - val_loss: 0.7083
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 196ms/step - accuracy: 0.5381 - loss: 0.6549 - val_accuracy: 0.5038 - val_loss: 0.7230
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 196ms/step - accuracy: 0.5393 - loss: 0.6452 - val_accuracy: 0.4952 - val_loss: 0.7158
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 199ms/step - accuracy: 0.5398 - loss: 0.6439 - val_accuracy: 0.5042 - val_loss: 0.7398

# %%
# Step 4: Evaluate the Model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.5106 - loss: 0.7347
# Test Loss: 0.7358, Test Accuracy: 0.5021

# %%
# Step 5: Make Predictions
predictions = model.predict(x_test[:10])  # Predict sentiment for the first 10 test reviews
print("Predictions:", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predictions: [[0.4667673 ]
#  [0.4667673 ]
#  [0.0482513 ]
#  [0.46676728]
#  [0.4667673 ]
#  [0.4667674 ]
#  [0.95889676]
#  [0.46676725]
#  [0.4667674 ]
#  [0.46676734]]

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
